# %%
import pandas as pd
df=pd.read_csv("dems.csv")
df.head()
# Out:
#    Group  MR Delay  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0         0    2    27  0.0  1987  0.696  0.883
# 1      0       457    2    30  0.0  2004  0.681  0.876
# 2      0         0    3    28  0.0  1215  0.710  1.444
# 3      0       538    3    27  0.0  1200  0.718  1.462
# 4      0         0    4    28  0.0  1689  0.712  1.039

# %%
# !pip install qiskit scikit-learn

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.circuit.library import ZZFeatureMap, TwoLocal
from qiskit_aer.primitives import Sampler
#from qiskit.utils import algorithm_globals
from qiskit.circuit.random import random_circuit
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC

# Set seed for reproducibility
seed = 45

import pandas as pd

df = pd.read_csv('dems.csv')
df.head()
X=df.drop('Group',axis=1)
y=df['Group']
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

"""
# Scale the data (important for feature maps)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
"""
# --- 2. Quantum Kernel Definition ---
# Define a quantum feature map
# ZZFeatureMap is a common choice for QSVC
adhoc_dimension=2
feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, insert_barriers=True, reps=3,entanglement='full')

# Define the quantum kernel
sampler = Sampler()
adhoc_kernel = FidelityQuantumKernel(feature_map=feature_map)
#quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# --- 3. Train and Evaluate the Quantum Support Vector Classifier (QSVC) ---
# Initialize QSVC
qsvc = QSVC(quantum_kernel=adhoc_kernel)

# Train the QSVC model
print("Training QSVC...")
qsvc.fit(X_train, y_train.values.ravel())
print("Training finished.")

# Evaluate the QSVC model
score_qsvc = qsvc.score(X_test, y_test)
print(f"QSVC test accuracy: {score_qsvc}")

# --- (Optional) Compare with a classical SVM ---
print("\nComparing with a classical SVM...")
classical_svm = SVC(kernel='rbf')
classical_svm.fit(X_train, y_train)
score_classical = classical_svm.score(X_test, y_test)
print(f"Classical SVM test accuracy: {score_classical}")
#print(qsvc.predict([5.1,3.5, 1.2, 0.2]))
# --- (Optional) Visualize the Feature Map (requires matplotlib) ---
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from qiskit.visualization import circuit_drawer
# feature_map.draw(output='mpl')
# plt.title("ZZ Feature Map")
# plt.show()
# Out:
# ...
# Training QSVC...
# Training finished.
# QSVC test accuracy: 0.578125
#
# Comparing with a classical SVM...
# Classical SVM test accuracy: 0.578125

# %%
# !pip install qiskit scikit-learn

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.circuit.library import ZZFeatureMap, TwoLocal
from qiskit_aer.primitives import Sampler
#from qiskit.utils import algorithm_globals
from qiskit.circuit.random import random_circuit
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC

# Set seed for reproducibility
seed = 45

import pandas as pd

df = pd.read_csv('dems.csv')
df.head()
X=df.drop('Group',axis=1)
y=df['Group']
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

"""
# Scale the data (important for feature maps)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
"""
# --- 2. Quantum Kernel Definition ---
# Define a quantum feature map
# ZZFeatureMap is a common choice for QSVC
adhoc_dimension=2
feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, insert_barriers=True, reps=3,entanglement='linear')

# Define the quantum kernel
sampler = Sampler()
adhoc_kernel = FidelityQuantumKernel(feature_map=feature_map)
#quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# --- 3. Train and Evaluate the Quantum Support Vector Classifier (QSVC) ---
# Initialize QSVC
qsvc = QSVC(quantum_kernel=adhoc_kernel)

# Train the QSVC model
print("Training QSVC...")
qsvc.fit(X_train, y_train.values.ravel())
print("Training finished.")

# Evaluate the QSVC model
score_qsvc = qsvc.score(X_test, y_test)
print(f"QSVC test accuracy: {score_qsvc}")

# --- (Optional) Compare with a classical SVM ---
print("\nComparing with a classical SVM...")
classical_svm = SVC(kernel='rbf')
classical_svm.fit(X_train, y_train)
score_classical = classical_svm.score(X_test, y_test)
print(f"Classical SVM test accuracy: {score_classical}")
#print(qsvc.predict([5.1,3.5, 1.2, 0.2]))
# --- (Optional) Visualize the Feature Map (requires matplotlib) ---
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from qiskit.visualization import circuit_drawer
# feature_map.draw(output='mpl')
# plt.title("ZZ Feature Map")
# plt.show()
# Out:
# ...
# Training QSVC...
# Training finished.
# QSVC test accuracy: 0.8125
#
# Comparing with a classical SVM...
# Classical SVM test accuracy: 0.578125

# %%
# !pip install qiskit scikit-learn

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.circuit.library import ZZFeatureMap, TwoLocal
from qiskit_aer.primitives import Sampler
#from qiskit.utils import algorithm_globals
from qiskit.circuit.random import random_circuit
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC

# Set seed for reproducibility
seed = 45

import pandas as pd

df = pd.read_csv('dems.csv')
df.head()
X=df.drop('Group',axis=1)
y=df['Group']
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

"""
# Scale the data (important for feature maps)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
"""
# --- 2. Quantum Kernel Definition ---
# Define a quantum feature map
# ZZFeatureMap is a common choice for QSVC
adhoc_dimension=2
feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, insert_barriers=True, reps=3,entanglement='circular')

# Define the quantum kernel
sampler = Sampler()
adhoc_kernel = FidelityQuantumKernel(feature_map=feature_map)
#quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# --- 3. Train and Evaluate the Quantum Support Vector Classifier (QSVC) ---
# Initialize QSVC
qsvc = QSVC(quantum_kernel=adhoc_kernel)

# Train the QSVC model
print("Training QSVC...")
qsvc.fit(X_train, y_train.values.ravel())
print("Training finished.")

# Evaluate the QSVC model
score_qsvc = qsvc.score(X_test, y_test)
print(f"QSVC test accuracy: {score_qsvc}")

# --- (Optional) Compare with a classical SVM ---
print("\nComparing with a classical SVM...")
classical_svm = SVC(kernel='rbf')
classical_svm.fit(X_train, y_train)
score_classical = classical_svm.score(X_test, y_test)
print(f"Classical SVM test accuracy: {score_classical}")
#print(qsvc.predict([5.1,3.5, 1.2, 0.2]))
# --- (Optional) Visualize the Feature Map (requires matplotlib) ---
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from qiskit.visualization import circuit_drawer
# feature_map.draw(output='mpl')
# plt.title("ZZ Feature Map")
# plt.show()
# Out:
# ...
# Training QSVC...
# Training finished.
# QSVC test accuracy: 0.78125
#
# Comparing with a classical SVM...
# Classical SVM test accuracy: 0.578125

# %%
# !pip install qiskit_aer
# !pip install qiskit_machine_learning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 107.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 15.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 2.2.3
#     Uninstalling qiskit-2.2.3:
#       Successfully uninstalled qiskit-2.2.3
# ...

# %%
# !pip install qiskit scikit-learn

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.circuit.library import ZZFeatureMap, TwoLocal
from qiskit_aer.primitives import Sampler
#from qiskit.utils import algorithm_globals
from qiskit.circuit.random import random_circuit
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC

# Set seed for reproducibility
seed = 45

import pandas as pd

df = pd.read_csv('dems.csv')
df.head()
X=df.drop('Group',axis=1)
y=df['Group']
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

"""
# Scale the data (important for feature maps)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
"""
# --- 2. Quantum Kernel Definition ---
# Define a quantum feature map
# ZZFeatureMap is a common choice for QSVC
adhoc_dimension=2
feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, insert_barriers=True, reps=3,entanglement='circular')

# Define the quantum kernel
sampler = Sampler()
adhoc_kernel = FidelityQuantumKernel(feature_map=feature_map)
#quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# --- 3. Train and Evaluate the Quantum Support Vector Classifier (QSVC) ---
# Initialize QSVC
qsvc = QSVC(quantum_kernel=adhoc_kernel)

# Train the QSVC model
print("Training QSVC...")
qsvc.fit(X_train, y_train.values.ravel())
print("Training finished.")

# Evaluate the QSVC model
score_qsvc = qsvc.score(X_test, y_test)
print(f"QSVC test accuracy: {score_qsvc}")

# --- (Optional) Compare with a classical SVM ---
print("\nComparing with a classical SVM...")
classical_svm = SVC(kernel='rbf')
classical_svm.fit(X_train, y_train)
score_classical = classical_svm.score(X_test, y_test)
print(f"Classical SVM test accuracy: {score_classical}")
#print(qsvc.predict([5.1,3.5, 1.2, 0.2]))
# --- (Optional) Visualize the Feature Map (requires matplotlib) ---
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from qiskit.visualization import circuit_drawer
# feature_map.draw(output='mpl')
# plt.title("ZZ Feature Map")
# plt.show()
# Out:
# ...
# Training QSVC...
# Training finished.
# QSVC test accuracy: 0.953125
#
# Comparing with a classical SVM...
# Classical SVM test accuracy: 0.578125

# %%
import pandas as pd
dfs=pd.read_csv("dems.csv")
dfs.head()
# Out:
#    Group  MR Delay  SES  MMSE  CDR
# 0      0         0    2    27  0.0
# 1      0       457    2    30  0.0
# 2      0         0    3    28  0.0
# 3      0       538    3    27  0.0
# 4      0         0    4    28  0.0

# %%
# !pip install qiskit scikit-learn

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.circuit.library import ZZFeatureMap, TwoLocal
from qiskit_aer.primitives import Sampler
#from qiskit.utils import algorithm_globals
from qiskit.circuit.random import random_circuit
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC

# Set seed for reproducibility
seed = 45

import pandas as pd

df = pd.read_csv('dems.csv')
df.head()
X=df.drop('Group',axis=1)
y=df['Group']
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

"""
# Scale the data (important for feature maps)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
"""
# --- 2. Quantum Kernel Definition ---
# Define a quantum feature map
# ZZFeatureMap is a common choice for QSVC
adhoc_dimension=2
feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, insert_barriers=True, reps=3,entanglement='circular')

# Define the quantum kernel
sampler = Sampler()
adhoc_kernel = FidelityQuantumKernel(feature_map=feature_map)
#quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# --- 3. Train and Evaluate the Quantum Support Vector Classifier (QSVC) ---
# Initialize QSVC
qsvc = QSVC(quantum_kernel=adhoc_kernel)

# Train the QSVC model
print("Training QSVC...")
qsvc.fit(X_train, y_train.values.ravel())
print("Training finished.")

# Evaluate the QSVC model
score_qsvc = qsvc.score(X_test, y_test)
print(f"QSVC test accuracy: {score_qsvc}")

# --- (Optional) Compare with a classical SVM ---
print("\nComparing with a classical SVM...")
classical_svm = SVC(kernel='rbf')
classical_svm.fit(X_train, y_train)
score_classical = classical_svm.score(X_test, y_test)
print(f"Classical SVM test accuracy: {score_classical}")
#print(qsvc.predict([5.1,3.5, 1.2, 0.2]))
# --- (Optional) Visualize the Feature Map (requires matplotlib) ---
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from qiskit.visualization import circuit_drawer
# feature_map.draw(output='mpl')
# plt.title("ZZ Feature Map")
# plt.show()
# Out:
# ...
# Training QSVC...
# Training finished.
# QSVC test accuracy: 0.953125
#
# Comparing with a classical SVM...
# Classical SVM test accuracy: 0.578125
